# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import KFold
import numpy as np

# Model configuration
batch_size = 50
img_width, img_height, img_num_channels = 32, 32, 3
loss_function = sparse_categorical_crossentropy
no_classes = 100
no_epochs = 25
optimizer = Adam()
verbosity = 1
num_folds = 10

# Load CIFAR-10 data
(input_train, target_train), (input_test, target_test) = cifar10.load_data()

# Determine shape of the data
input_shape = (img_width, img_height, img_num_channels)

# Parse numbers as floats
input_train = input_train.astype('float32')
input_test = input_test.astype('float32')

# Normalize data
input_train = input_train / 255
input_test = input_test / 255

# Define per-fold score containers
acc_per_fold = []
loss_per_fold = []

# Merge inputs and targets
inputs = np.concatenate((input_train, input_test), axis=0)
targets = np.concatenate((target_train, target_test), axis=0)

# Define the K-fold Cross Validator
kfold = KFold(n_splits=num_folds, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(inputs, targets):

  # Define the model architecture
  model = Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dense(128, activation='relu'))
  model.add(Dense(no_classes, activation='softmax'))

  # Compile the model
  model.compile(loss=loss_function,
                optimizer=optimizer,
                metrics=['accuracy'])


  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')

  # Fit data to model
  history = model.fit(inputs[train], targets[train],
              batch_size=batch_size,
              epochs=no_epochs,
              verbose=verbosity)

  # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step
# 2022-10-24 09:18:20.640340: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 09:18:20.733876: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 09:18:20.734679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 09:18:20.735988: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-24 09:18:20.736322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 09:18:20.737018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 09:18:20.737677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 09:18:23.112763: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 09:18:23.113688: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 09:18:23.114373: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-24 09:18:23.114966: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# ------------------------------------------------------------------------
# Training for fold 1 ...
# 2022-10-24 09:18:24.472586: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 663552000 exceeds 10% of free system memory.
# 2022-10-24 09:18:25.230054: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 663552000 exceeds 10% of free system memory.
# 2022-10-24 09:18:25.777804: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/25
# 2022-10-24 09:18:27.092274: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 1080/1080 [==============================] - 10s 3ms/step - loss: 1.5553 - accuracy: 0.4404
# Epoch 2/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.1031 - accuracy: 0.6089
# Epoch 3/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9372 - accuracy: 0.6711
# Epoch 4/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8200 - accuracy: 0.7134
# Epoch 5/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7256 - accuracy: 0.7472
# Epoch 6/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6367 - accuracy: 0.7771
# Epoch 7/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5586 - accuracy: 0.8046
# Epoch 8/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4856 - accuracy: 0.8285
# Epoch 9/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4162 - accuracy: 0.8531
# Epoch 10/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3547 - accuracy: 0.8742
# Epoch 11/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3043 - accuracy: 0.8929
# Epoch 12/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2565 - accuracy: 0.9080
# Epoch 13/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2128 - accuracy: 0.9257
# Epoch 14/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1824 - accuracy: 0.9352
# Epoch 15/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1609 - accuracy: 0.9429
# Epoch 16/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1449 - accuracy: 0.9473
# Epoch 17/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1326 - accuracy: 0.9530
# Epoch 18/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1117 - accuracy: 0.9610
# Epoch 19/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1068 - accuracy: 0.9622
# Epoch 20/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1016 - accuracy: 0.9654
# Epoch 21/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.0975 - accuracy: 0.9658
# Epoch 22/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.0923 - accuracy: 0.9684
# Epoch 23/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.0883 - accuracy: 0.9699
# Epoch 24/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.0761 - accuracy: 0.9740
# Epoch 25/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.0892 - accuracy: 0.9688
# Score for fold 1: loss of 2.1541025638580322; accuracy of 70.03333568572998%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# 2022-10-24 09:19:49.795752: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 663552000 exceeds 10% of free system memory.
# 2022-10-24 09:19:50.542639: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 663552000 exceeds 10% of free system memory.
# Epoch 1/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.5431 - accuracy: 0.4370
# Epoch 2/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.1570 - accuracy: 0.5872
# Epoch 3/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.0152 - accuracy: 0.6408
# Epoch 4/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9214 - accuracy: 0.6775
# Epoch 5/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8467 - accuracy: 0.7019
# Epoch 6/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7810 - accuracy: 0.7272
# Epoch 7/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7227 - accuracy: 0.7481
# Epoch 8/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6704 - accuracy: 0.7633
# Epoch 9/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6203 - accuracy: 0.7824
# Epoch 10/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5778 - accuracy: 0.7974
# Epoch 11/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5352 - accuracy: 0.8126
# Epoch 12/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4914 - accuracy: 0.8261
# Epoch 13/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4440 - accuracy: 0.8435
# Epoch 14/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4128 - accuracy: 0.8535
# Epoch 15/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3682 - accuracy: 0.8702
# Epoch 16/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3393 - accuracy: 0.8782
# Epoch 17/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3021 - accuracy: 0.8920
# Epoch 18/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2695 - accuracy: 0.9054
# Epoch 19/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2446 - accuracy: 0.9132
# Epoch 20/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2194 - accuracy: 0.9229
# Epoch 21/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1964 - accuracy: 0.9296
# Epoch 22/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1723 - accuracy: 0.9389
# Epoch 23/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1654 - accuracy: 0.9403
# Epoch 24/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1510 - accuracy: 0.9458
# Epoch 25/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1392 - accuracy: 0.9496
# Score for fold 2: loss of 1.9614964723587036; accuracy of 67.1999990940094%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# 2022-10-24 09:21:15.236778: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 663552000 exceeds 10% of free system memory.
# Epoch 1/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.6490 - accuracy: 0.3969
# Epoch 2/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.2342 - accuracy: 0.5587
# Epoch 3/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.0882 - accuracy: 0.6147
# Epoch 4/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9942 - accuracy: 0.6471
# Epoch 5/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9222 - accuracy: 0.6750
# Epoch 6/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8562 - accuracy: 0.6979
# Epoch 7/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8000 - accuracy: 0.7180
# Epoch 8/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7439 - accuracy: 0.7383
# Epoch 9/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6963 - accuracy: 0.7549
# Epoch 10/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6425 - accuracy: 0.7742
# Epoch 11/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5939 - accuracy: 0.7899
# Epoch 12/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5533 - accuracy: 0.8035
# Epoch 13/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5082 - accuracy: 0.8209
# Epoch 14/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4710 - accuracy: 0.8336
# Epoch 15/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4300 - accuracy: 0.8485
# Epoch 16/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3938 - accuracy: 0.8599
# Epoch 17/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3567 - accuracy: 0.8740
# Epoch 18/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3291 - accuracy: 0.8826
# Epoch 19/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2990 - accuracy: 0.8936
# Epoch 20/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2693 - accuracy: 0.9040
# Epoch 21/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2493 - accuracy: 0.9121
# Epoch 22/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2291 - accuracy: 0.9182
# Epoch 23/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2051 - accuracy: 0.9279
# Epoch 24/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1875 - accuracy: 0.9330
# Epoch 25/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1753 - accuracy: 0.9383
# Score for fold 3: loss of 2.070075273513794; accuracy of 64.81666564941406%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.5839 - accuracy: 0.4166
# Epoch 2/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.2065 - accuracy: 0.5651
# Epoch 3/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.0471 - accuracy: 0.6284
# Epoch 4/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9468 - accuracy: 0.6652
# Epoch 5/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8705 - accuracy: 0.6941
# Epoch 6/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8068 - accuracy: 0.7163
# Epoch 7/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7534 - accuracy: 0.7359
# Epoch 8/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7030 - accuracy: 0.7522
# Epoch 9/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6593 - accuracy: 0.7684
# Epoch 10/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6165 - accuracy: 0.7846
# Epoch 11/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5728 - accuracy: 0.7965
# Epoch 12/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5335 - accuracy: 0.8109
# Epoch 13/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4986 - accuracy: 0.8234
# Epoch 14/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4616 - accuracy: 0.8374
# Epoch 15/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4285 - accuracy: 0.8481
# Epoch 16/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4008 - accuracy: 0.8555
# Epoch 17/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3698 - accuracy: 0.8689
# Epoch 18/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3408 - accuracy: 0.8790
# Epoch 19/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3176 - accuracy: 0.8871
# Epoch 20/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2861 - accuracy: 0.8993
# Epoch 21/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2749 - accuracy: 0.9024
# Epoch 22/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2516 - accuracy: 0.9102
# Epoch 23/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2267 - accuracy: 0.9200
# Epoch 24/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2145 - accuracy: 0.9233
# Epoch 25/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1986 - accuracy: 0.9289
# Score for fold 4: loss of 1.865727186203003; accuracy of 66.79999828338623%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.5280 - accuracy: 0.4445
# Epoch 2/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.1417 - accuracy: 0.5935
# Epoch 3/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.0062 - accuracy: 0.6449
# Epoch 4/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9199 - accuracy: 0.6759
# Epoch 5/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8491 - accuracy: 0.6985
# Epoch 6/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7901 - accuracy: 0.7212
# Epoch 7/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7434 - accuracy: 0.7378
# Epoch 8/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7050 - accuracy: 0.7513
# Epoch 9/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6608 - accuracy: 0.7668
# Epoch 10/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6242 - accuracy: 0.7795
# Epoch 11/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5856 - accuracy: 0.7937
# Epoch 12/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5498 - accuracy: 0.8059
# Epoch 13/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5170 - accuracy: 0.8156
# Epoch 14/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4759 - accuracy: 0.8310
# Epoch 15/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4450 - accuracy: 0.8420
# Epoch 16/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4169 - accuracy: 0.8512
# Epoch 17/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3870 - accuracy: 0.8622
# Epoch 18/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3558 - accuracy: 0.8741
# Epoch 19/25
# 1080/1080 [==============================] - 4s 3ms/step - loss: 0.3295 - accuracy: 0.8832
# Epoch 20/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3088 - accuracy: 0.8908
# Epoch 21/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2845 - accuracy: 0.8977
# Epoch 22/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2660 - accuracy: 0.9054
# Epoch 23/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2398 - accuracy: 0.9144
# Epoch 24/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2270 - accuracy: 0.9189
# Epoch 25/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2135 - accuracy: 0.9237
# Score for fold 5: loss of 1.7094918489456177; accuracy of 67.68333315849304%
# ------------------------------------------------------------------------
# Training for fold 6 ...
# Epoch 1/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.5326 - accuracy: 0.4446
# Epoch 2/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.1443 - accuracy: 0.5932
# Epoch 3/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.0021 - accuracy: 0.6452
# Epoch 4/25
# 1080/1080 [==============================] - 4s 3ms/step - loss: 0.9095 - accuracy: 0.6800
# Epoch 5/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8352 - accuracy: 0.7088
# Epoch 6/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7700 - accuracy: 0.7321
# Epoch 7/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7111 - accuracy: 0.7519
# Epoch 8/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6610 - accuracy: 0.7686
# Epoch 9/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6131 - accuracy: 0.7837
# Epoch 10/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5666 - accuracy: 0.8002
# Epoch 11/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5261 - accuracy: 0.8148
# Epoch 12/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4803 - accuracy: 0.8311
# Epoch 13/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4398 - accuracy: 0.8447
# Epoch 14/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4020 - accuracy: 0.8584
# Epoch 15/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3695 - accuracy: 0.8693
# Epoch 16/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3348 - accuracy: 0.8819
# Epoch 17/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3048 - accuracy: 0.8923
# Epoch 18/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2778 - accuracy: 0.9006
# Epoch 19/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2489 - accuracy: 0.9113
# Epoch 20/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2283 - accuracy: 0.9193
# Epoch 21/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2077 - accuracy: 0.9260
# Epoch 22/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1882 - accuracy: 0.9331
# Epoch 23/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1757 - accuracy: 0.9386
# Epoch 24/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1626 - accuracy: 0.9430
# Epoch 25/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1548 - accuracy: 0.9450
# Score for fold 6: loss of 2.121264696121216; accuracy of 65.03333449363708%
# ------------------------------------------------------------------------
# Training for fold 7 ...
# Epoch 1/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.5040 - accuracy: 0.4524
# Epoch 2/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.1205 - accuracy: 0.6046
# Epoch 3/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9796 - accuracy: 0.6544
# Epoch 4/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8841 - accuracy: 0.6897
# Epoch 5/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8095 - accuracy: 0.7161
# Epoch 6/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7407 - accuracy: 0.7386
# Epoch 7/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6828 - accuracy: 0.7600
# Epoch 8/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6265 - accuracy: 0.7794
# Epoch 9/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5739 - accuracy: 0.7969
# Epoch 10/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5210 - accuracy: 0.8152
# Epoch 11/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4738 - accuracy: 0.8321
# Epoch 12/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4261 - accuracy: 0.8487
# Epoch 13/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3872 - accuracy: 0.8622
# Epoch 14/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3513 - accuracy: 0.8743
# Epoch 15/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3117 - accuracy: 0.8884
# Epoch 16/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2876 - accuracy: 0.8969
# Epoch 17/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2554 - accuracy: 0.9089
# Epoch 18/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2216 - accuracy: 0.9215
# Epoch 19/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2052 - accuracy: 0.9271
# Epoch 20/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1868 - accuracy: 0.9326
# Epoch 21/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1685 - accuracy: 0.9400
# Epoch 22/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1676 - accuracy: 0.9410
# Epoch 23/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1391 - accuracy: 0.9490
# Epoch 24/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1253 - accuracy: 0.9551
# Epoch 25/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1340 - accuracy: 0.9528
# Score for fold 7: loss of 2.346248149871826; accuracy of 65.78333377838135%
# ------------------------------------------------------------------------
# Training for fold 8 ...
# Epoch 1/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.5780 - accuracy: 0.4216
# Epoch 2/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.1562 - accuracy: 0.5865
# Epoch 3/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.0216 - accuracy: 0.6371
# Epoch 4/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9291 - accuracy: 0.6711
# Epoch 5/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8555 - accuracy: 0.6991
# Epoch 6/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7915 - accuracy: 0.7196
# Epoch 7/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7347 - accuracy: 0.7424
# Epoch 8/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6840 - accuracy: 0.7584
# Epoch 9/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6355 - accuracy: 0.7764
# Epoch 10/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5927 - accuracy: 0.7904
# Epoch 11/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5491 - accuracy: 0.8067
# Epoch 12/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5116 - accuracy: 0.8175
# Epoch 13/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4706 - accuracy: 0.8330
# Epoch 14/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4369 - accuracy: 0.8447
# Epoch 15/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4065 - accuracy: 0.8553
# Epoch 16/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3685 - accuracy: 0.8691
# Epoch 17/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3426 - accuracy: 0.8767
# Epoch 18/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3135 - accuracy: 0.8884
# Epoch 19/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2936 - accuracy: 0.8947
# Epoch 20/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2633 - accuracy: 0.9057
# Epoch 21/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2419 - accuracy: 0.9131
# Epoch 22/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2226 - accuracy: 0.9196
# Epoch 23/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2028 - accuracy: 0.9282
# Epoch 24/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1909 - accuracy: 0.9319
# Epoch 25/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1674 - accuracy: 0.9404
# Score for fold 8: loss of 1.9042431116104126; accuracy of 67.1999990940094%
# ------------------------------------------------------------------------
# Training for fold 9 ...
# Epoch 1/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.5831 - accuracy: 0.4216
# Epoch 2/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.1483 - accuracy: 0.5925
# Epoch 3/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9979 - accuracy: 0.6506
# Epoch 4/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9085 - accuracy: 0.6806
# Epoch 5/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8382 - accuracy: 0.7071
# Epoch 6/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7717 - accuracy: 0.7306
# Epoch 7/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7177 - accuracy: 0.7484
# Epoch 8/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6665 - accuracy: 0.7654
# Epoch 9/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6211 - accuracy: 0.7817
# Epoch 10/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5741 - accuracy: 0.7961
# Epoch 11/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5309 - accuracy: 0.8130
# Epoch 12/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4873 - accuracy: 0.8288
# Epoch 13/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4491 - accuracy: 0.8408
# Epoch 14/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4096 - accuracy: 0.8550
# Epoch 15/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3710 - accuracy: 0.8689
# Epoch 16/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3386 - accuracy: 0.8809
# Epoch 17/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3055 - accuracy: 0.8931
# Epoch 18/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2789 - accuracy: 0.9017
# Epoch 19/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2537 - accuracy: 0.9114
# Epoch 20/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2264 - accuracy: 0.9194
# Epoch 21/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2113 - accuracy: 0.9254
# Epoch 22/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1929 - accuracy: 0.9312
# Epoch 23/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1773 - accuracy: 0.9374
# Epoch 24/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1639 - accuracy: 0.9423
# Epoch 25/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1420 - accuracy: 0.9495
# Score for fold 9: loss of 1.9408073425292969; accuracy of 67.35000014305115%
# ------------------------------------------------------------------------
# Training for fold 10 ...
# Epoch 1/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.5200 - accuracy: 0.4455
# Epoch 2/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 1.1003 - accuracy: 0.6096
# Epoch 3/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.9448 - accuracy: 0.6686
# Epoch 4/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.8427 - accuracy: 0.7051
# Epoch 5/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7630 - accuracy: 0.7315
# Epoch 6/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.7022 - accuracy: 0.7523
# Epoch 7/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.6449 - accuracy: 0.7746
# Epoch 8/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5929 - accuracy: 0.7906
# Epoch 9/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.5436 - accuracy: 0.8089
# Epoch 10/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4948 - accuracy: 0.8252
# Epoch 11/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4517 - accuracy: 0.8399
# Epoch 12/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.4084 - accuracy: 0.8551
# Epoch 13/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3728 - accuracy: 0.8671
# Epoch 14/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.3385 - accuracy: 0.8820
# Epoch 15/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2980 - accuracy: 0.8948
# Epoch 16/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2724 - accuracy: 0.9030
# Epoch 17/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2430 - accuracy: 0.9148
# Epoch 18/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.2256 - accuracy: 0.9196
# Epoch 19/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1935 - accuracy: 0.9324
# Epoch 20/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1827 - accuracy: 0.9340
# Epoch 21/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1662 - accuracy: 0.9402
# Epoch 22/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1544 - accuracy: 0.9451
# Epoch 23/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1443 - accuracy: 0.9492
# Epoch 24/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1318 - accuracy: 0.9535
# Epoch 25/25
# 1080/1080 [==============================] - 3s 3ms/step - loss: 0.1277 - accuracy: 0.9544
# Score for fold 10: loss of 1.9735445976257324; accuracy of 69.16666626930237%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 2.1541025638580322 - Accuracy: 70.03333568572998%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 1.9614964723587036 - Accuracy: 67.1999990940094%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 2.070075273513794 - Accuracy: 64.81666564941406%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 1.865727186203003 - Accuracy: 66.79999828338623%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 1.7094918489456177 - Accuracy: 67.68333315849304%
# ------------------------------------------------------------------------
# > Fold 6 - Loss: 2.121264696121216 - Accuracy: 65.03333449363708%
# ------------------------------------------------------------------------
# > Fold 7 - Loss: 2.346248149871826 - Accuracy: 65.78333377838135%
# ------------------------------------------------------------------------
# > Fold 8 - Loss: 1.9042431116104126 - Accuracy: 67.1999990940094%
# ------------------------------------------------------------------------
# > Fold 9 - Loss: 1.9408073425292969 - Accuracy: 67.35000014305115%
# ------------------------------------------------------------------------
# > Fold 10 - Loss: 1.9735445976257324 - Accuracy: 69.16666626930237%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 67.1066665649414 (+- 1.5686374216744658)
# > Loss: 2.0047001242637634
# ------------------------------------------------------------------------
